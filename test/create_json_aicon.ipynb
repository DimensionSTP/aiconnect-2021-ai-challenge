# %%
# 다크넷 깃 클론(클론 전에 구글 드라이브 마운트 해놓을 것)
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15185, done.
# remote: Total 15185 (delta 0), reused 0 (delta 0), pack-reused 15185
# Receiving objects: 100% (15185/15185), 13.56 MiB | 25.42 MiB/s, done.
# Resolving deltas: 100% (10308/10308), done.

# %%
# 다크넷 폴더 진입
# %cd /content/darknet/
# Out:
# /content/darknet

# %%
# 메이크 파일 수정(OPENCV, GPU, CUDNN, CUDNN_HALF on)
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile

# %%
#gpu 가능한지 확인
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# 메이크
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# 구글 드라이브 경로 단축 저장
# !ln -s /content/drive/MyDrive/ /gdrive

# %%
# 구글 마이드라이브 진입
# %cd /gdrive/
# Out:
# /content/drive/MyDrive

# %%
# 다크넷 폴더 진입
# %cd /content/darknet/
# Out:
# /content/darknet

# %%
# cfg 파일 복사(cfg 파일 설정 확인 할 것)
# !cp /gdrive/aicon/yolov4-tiny-obj.cfg ./cfg

# %%
# obj.names, data 복사(파일 설정 확인 할 것)
# !cp /gdrive/aicon/obj.names ./data
# !cp /gdrive/aicon/obj.data  ./data

# %%
# cfg 다크넷 학습이 아닌 실행 모드로 변경 - batch, subdivisions = 1
# %cd cfg
# !sed -i 's/batch=64/batch=1/' yolov4-tiny-obj.cfg
# !sed -i 's/subdivisions=16/subdivisions=1/' yolov4-tiny-obj.cfg
# %cd ..
# Out:
# /content/darknet/cfg
# /content/darknet

# %%
# 테스트 하려는 데이터들 복사
# !cp /gdrive/aicon/test_images.tar.gz ../

# %%
# 복사된 데이터들 데이터 하위 폴더에 압축 풀기
# !tar -zxvf ../test_images.tar.gz -C data/
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# images/image_05622839114498.jpg
# images/image_49079692108672.jpg
# images/image_59810643783060.jpg
# images/image_35191457276119.jpg
# images/image_13421555111202.jpg
# images/image_18350488163802.jpg
# images/image_48259450508925.jpg
# images/image_35214592429660.jpg
# images/image_66652249373150.jpg
# images/image_65306878175348.jpg
# images/image_92133259602578.jpg
# images/image_66553372709979.jpg
# images/image_31614642853145.jpg
# images/image_00976564535347.jpg
# images/image_58387637872380.jpg
# images/image_38389787666280.jpg
# images/image_61693689467855.jpg
# images/image_50134998018475.jpg
# images/image_06830785632065.jpg
# images/image_46694134335359.jpg
# images/image_75552736562210.jpg
# images/image_84888254724985.jpg
# images/image_27197243405134.jpg
# images/image_11841218158303.jpg
# images/image_23553800432555.jpg
# images/image_24902045181538.jpg
# images/image_34500992771155.jpg
# images/image_91588390152432.jpg
# ...

# %%
# images.py 복사(코드 확인 할 것)
# !cp /gdrive/aicon/generate_images.py ./

# %%
# images.txt 생성(data에 생성된 images.txt 제대로 생성되었는지 확인 할 것)
# !python generate_images.py

# %%
# 다크넷 테스트 디텍터(multi images output -> json, txt) 실행(test, obj.data_path, cfg_path, weight_path, -ext_output -dont_show  -thresh 0.xx -out <data/images.txt> file_name.json_path file_name.txt_path)
# !./darknet detector test data/obj.data cfg/yolov4-tiny-obj.cfg /gdrive/aicon/backup/yolov4-tiny-obj_best.weights -ext_output -dont_show  -thresh 0.75 -out <data/images.txt> /gdrive/aicon/result_backup/result.json /gdrive/aicon/result_backup/result.txt
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 700, cudnn_half = 1, GPU: Tesla V100-SXM2-16GB
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#    8 route  2 7 	                           ->  104 x 104 x 128
# ...
